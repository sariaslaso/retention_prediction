# %%
import pandas as pd
import numpy as np

# %%
data_descriptions = pd.read_csv('../data/data_descriptions.csv')
pd.set_option('display.max_colwidth', None)
data_descriptions
# Out:
#                                          Column_name  \
# 0                                    subscription_id
# 1                                     observation_dt
# 2                                        is_retained
# 3                                  specialization_id
# 4                      cnt_courses_in_specialization
# 5                              specialization_domain
# 6                        is_professional_certificate
# 7                             is_gateway_certificate
# 8                    learner_days_since_registration
# 9                              learner_country_group
# 10                                    learner_gender
# 11                  learner_cnt_other_courses_active
# 12             learner_cnt_other_courses_paid_active
# 13         learner_cnt_other_courses_items_completed
# 14    learner_cnt_other_courses_paid_items_completed
# 15               learner_cnt_other_transactions_past
# 16                             learner_other_revenue
# ...

# %% [markdown]
# #### load the data

# %%
dataset = pd.read_csv("../data/dataset.csv", low_memory = False)
# dataset.info()

# %%
dataset.shape
# Out:
# (413955, 37)

# %%
dataset.isna().values.ravel().sum()
# Out:
# np.int64(36)

# %% [markdown]
# There are only 36 missing values in the data, I will remove the rows that are missing values and and carry on the analysis.

# %%
dataset.isnull().sum().to_frame()
# Out:
#                                                   0
# subscription_id                                   0
# observation_dt                                    0
# is_retained                                       1
# specialization_id                                 1
# cnt_courses_in_specialization                     1
# specialization_domain                             2
# is_professional_certificate                       1
# is_gateway_certificate                            1
# learner_days_since_registration                   1
# learner_country_group                             1
# learner_gender                                    1
# learner_cnt_other_courses_active                  1
# learner_cnt_other_courses_paid_active             1
# learner_cnt_other_courses_items_completed         1
# learner_cnt_other_courses_paid_items_completed    1
# learner_cnt_other_transactions_past               1
# learner_other_revenue                             1
# ...

# %%
# drop na values from the data
dataset = dataset.dropna()

# %%
# split into training, validation and test set

# %%
# remove outliers from training data
dataset.quantile(q = 0.25, numeric_only = True)
# Out:
# is_retained                                          0.00
# cnt_courses_in_specialization                        5.00
# learner_days_since_registration                     71.00
# learner_cnt_other_courses_active                     0.00
# learner_cnt_other_courses_paid_active                0.00
# learner_cnt_other_courses_items_completed            0.00
# learner_cnt_other_courses_paid_items_completed       0.00
# learner_cnt_other_transactions_past                  0.00
# learner_other_revenue                                0.00
# subscription_period_order                            1.00
# days_since_last_payment                              5.00
# days_til_next_payment_due                           10.00
# cnt_enrollments_started_before_payment_period        1.00
# cnt_enrollments_completed_before_payment_period      0.00
# cnt_enrollments_active_before_payment_period         1.00
# cnt_items_completed_before_payment_period            7.00
# ...
